# %% [markdown]
# # Machine Learning e Data Science com Python de A à Z IA Expert Academy - Regressão

# %% [markdown]
# # Regressão linear simples

# %% [markdown]
# ## Base plano saúde

# %% [markdown]
# **O objetivo deste case é fazer uma regressão linear, prevendo o custo do planos de saúde, dependendo da idade da pessoa.**

# %% [markdown]
# **Instalação, atualização e importação de bibliotecas:**
# *   plotly: visualização de gráficos interativos
# *   seaborn:visualização de gráficos
# *  matplotlib: geração de gráficos
# *   pandas: carregar o arquivo csv
# *   numpy: biblioteca científica do python

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
#      |████████████████████████████████| 27.7 MB 1.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.6.0

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
base_plano_saude = pd.read_csv('plano_saude.csv')
base_plano_saude
# Out:
#    idade  custo
# 0     18    871
# 1     23   1132
# 2     28   1242
# 3     33   1356
# 4     38   1488
# 5     43   1638
# 6     48   2130
# 7     53   2454
# 8     58   3066
# 9     63   4090

# %% [markdown]
# **Criação da variável x (atributo previsor: idade) e variável y (atributo custo).**

# %% [markdown]
# Criação da variável x_plano_saúde, recebe a função iloc para selecionar o conjunto de registros.Os atributos [:] significa todas as linhas e [0] a primeira coluna (idade: atributo previsor). Values converte para numpy array.

# %%
X_plano_saude = base_plano_saude.iloc[:, 0].values
X_plano_saude
# Out:
# array([18, 23, 28, 33, 38, 43, 48, 53, 58, 63])

# %% [markdown]
# Criação da variável y_plano_saúde. Os atributos [:] significa todas as linhas e [1] a segunda coluna (Atributo custo: objetivo).

# %%
y_plano_saude = base_plano_saude.iloc[:, 1].values
y_plano_saude
# Out:
# array([ 871, 1132, 1242, 1356, 1488, 1638, 2130, 2454, 3066, 4090])

# %% [markdown]
# Encontrando a correlação...O resultado mostra valores iguais em formato de matriz, o que indica uma correlação perfeita (muito forte). Indicando que o algoritmo de regressão linear pode funcionar muito bem.

# %%
np.corrcoef(X_plano_saude, y_plano_saude)
# Out:
# array([[1.        , 0.93091958],
#        [0.93091958, 1.        ]])

# %%
X_plano_saude.shape
# Out:
# (10,)

# %% [markdown]
# É necessário colocar no formato abaixo (10 linhas e 1 coluna) por causa da biblioteca utilizada sklearn.

# %%
X_plano_saude = X_plano_saude.reshape(-1,1)
X_plano_saude.shape
# Out:
# (10, 1)

# %% [markdown]
# Importação da classe de regressão linear, criação da variável regressor_plano_saude e treinamento (encontrar b0 e b1).

# %%
from sklearn.linear_model import LinearRegression
regressor_plano_saude = LinearRegression()
regressor_plano_saude.fit(X_plano_saude, y_plano_saude)
# Out:
# LinearRegression()

# %% [markdown]
# Início da linha de regressão

# %%
# b0
regressor_plano_saude.intercept_
# Out:
# -558.9490909090912

# %% [markdown]
# Declive da linha de regressão

# %%
# b1
regressor_plano_saude.coef_
# Out:
# array([61.86787879])

# %% [markdown]
# Previsões:

# %%
previsoes = regressor_plano_saude.predict(X_plano_saude)
previsoes
# Out:
# array([ 554.67272727,  864.01212121, 1173.35151515, 1482.69090909,
#        1792.03030303, 2101.36969697, 2410.70909091, 2720.04848485,
#        3029.38787879, 3338.72727273])

# %% [markdown]
# É necessário transformar em vetor para visualizar o gráfico (função ravel)

# %%
X_plano_saude.ravel()
# Out:
# array([18, 23, 28, 33, 38, 43, 48, 53, 58, 63])

# %% [markdown]
# Gerando um gráfico para demonstrar as previsões:
#
# *   y = previsões
# *   x = idade
#
# Em vermelho aparece a reta que é o modelo (a previsão) e em azul temos os valores reais.

# %%
grafico = px.scatter(x = X_plano_saude.ravel(), y = y_plano_saude)
grafico.add_scatter(x = X_plano_saude.ravel(), y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="878fa33a-1ec6-4b93-8d1a-986940437223" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("878fa33a-1ec6-4b93-8d1a-986940437223")) {                    Plotly.newPlot(                        "878fa33a-1ec6-4b93-8d1a-986940437223",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[871,1132,1242,1356,1488,1638,2130,2454,3066,4090],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[554.6727272727271,864.012121212121,1173.351515151515,1482.6909090909091,1792.0303030303028,2101.3696969696966,2410.709090909091,2720.048484848485,3029.3878787878793,3338.727272727273],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoo ...

# %%
regressor_plano_saude.intercept_ + regressor_plano_saude.coef_ * 40
# Out:
# array([1915.76606061])

# %%
regressor_plano_saude.predict([[40]])
# Out:
# array([1915.76606061])

# %% [markdown]
# Score indica a qualidade do algoritmo (quanto mais próximo de 1, melhor)

# %%
regressor_plano_saude.score(X_plano_saude, y_plano_saude)
# Out:
# 0.8666112727879174

# %% [markdown]
# Biblioteca yellowbrick - resíduos (distância dos valores originais da linha de regressão)

# %%
from yellowbrick.regressor import ResidualsPlot
visualizador = ResidualsPlot(regressor_plano_saude)
visualizador.fit(X_plano_saude, y_plano_saude)
visualizador.poof()

# %% [markdown]
# ## Base preço das casas - MAE 172.604, 0.48

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# O objetivo é prever o custo (price) da casa de acordo com o seu tamanho (sqft_living).

# %%
base_casas = pd.read_csv('house_prices.csv')
base_casas
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
base_casas.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %% [markdown]
# A partir da função isnull observa-se valores faltantes. Nesse caso, retornou 0, não temos valores faltantes.

# %%
base_casas.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Correlações de um atributo com todos os outros

# %%
base_casas.corr()
# Out:
#                      id     price  ...  sqft_living15  sqft_lot15
# id             1.000000 -0.016762  ...      -0.002901   -0.138798
# price         -0.016762  1.000000  ...       0.585379    0.082447
# bedrooms       0.001286  0.308350  ...       0.391638    0.029244
# bathrooms      0.005160  0.525138  ...       0.568634    0.087175
# sqft_living   -0.012258  0.702035  ...       0.756420    0.183286
# sqft_lot      -0.132109  0.089661  ...       0.144608    0.718557
# floors         0.018525  0.256794  ...       0.279885   -0.011269
# waterfront    -0.002721  0.266369  ...       0.086463    0.030703
# view           0.011592  0.397293  ...       0.280439    0.072575
# condition     -0.023783  0.036362  ...      -0.092824   -0.003406
# grade          0.008130  0.667434  ...       0.713202    0.119248
# sqft_above    -0.010842  0.605567  ...       0.731870    0.194050
# sqft_basement -0.005151  0.323816  ...       0.200355    0.017276
# yr_built       0.021380  0.054012  ...       0.326229    0.070958
# yr_renovated  -0.016907  0.126434  ...      -0.002673    0.007854
# zipcode       -0.008224 -0.053203  ...      -0.279033   -0.147221
# lat           -0.001891  0.307003  ...       0.048858   -0.086419
# long           0.020799  0.021626  ...       0.334605    0.254451
# sqft_living15 -0.002901  0.585379  ...       1.000000    0.183192
# sqft_lot15    -0.138798  0.082447  ...       0.183192    1.000000
#
# [20 rows x 20 columns]

# %% [markdown]
# Mapa de correlação (calor), biblioteca seaborn (Quanto mais próximo do valor 1, maior a correlação)

# %%
figura = plt.figure(figsize=(20,20))
sns.heatmap(base_casas.corr(), annot=True);

# %% [markdown]
# Criando a variável x_casas (atributo previsor: metragem)

# %%
X_casas = base_casas.iloc[:,5:6].values
X_casas
# Out:
# array([[1180],
#        [2570],
#        [ 770],
#        ...,
#        [1020],
#        [1600],
#        [1020]])

# %% [markdown]
# Criando a variável y_casas (Objetivo: previsão do preço)

# %%
y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# Dividindo a base de teste e treinamento

# %%
from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size = 0.3, random_state = 0)

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 1), (15129,))

# %%
X_casas_teste.shape, y_casas_teste.shape
# Out:
# ((6484, 1), (6484,))

# %% [markdown]
# Criando o modelo de regressão

# %%
from sklearn.linear_model import LinearRegression
regressor_simples_casas = LinearRegression()
regressor_simples_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
# b0
regressor_simples_casas.intercept_
# Out:
# -37893.59850106726

# %%
# b1
regressor_simples_casas.coef_
# Out:
# array([278.32860644])

# %%
regressor_simples_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.49453356717789776

# %% [markdown]
# Coeficiente R2 (score): Quanto mais próximo de 1, melhor

# %%
regressor_simples_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.48889929019453027

# %%
previsoes = regressor_simples_casas.predict(X_casas_treinamento)
previsoes
# Out:
# array([348983.16445268, 365682.88083917, 758126.21592175, ...,
#        618961.91270098, 621745.1987654 , 624528.48482981])

# %% [markdown]
# Gráfico do modelo de treinamento (x= metragem, y=previsões de custo)

# %%
grafico = px.scatter(x = X_casas_treinamento.ravel(), y = previsoes)
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="f321da49-d323-4e04-80e7-7184182deea9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f321da49-d323-4e04-80e7-7184182deea9")) {                    Plotly.newPlot(                        "f321da49-d323-4e04-80e7-7184182deea9",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1390,1450,2860,1050,1240,1860,2070,2710,2030,1000,2730,1714,1310,1240,1070,1480,2120,1900,2410,1610,2420,2800,1620,1500,1270,1500,1810,2980,3190,2750,1780,2600,1680,1130,1330,1630,1430,1870,2120,1880,1200,2180,3190,2020,1590,1270,1720,1190,3010,1400,3010,2140,2490,1930,4580,2720,1520,1360,2410,1140,720,2780,1840,1550,1450,4050,2420,2730,3230,980,1240,2070,2320,1860,4010,2480,1270,990,1210,1930,1910,1730,2570,1050,1890,2050,2820,2970,2860,1500,1840,1420,520,4380,2680,670,3140,1530,2210,1580,5000,1220,4040,750,3100,1580,2260,1720,1280,930,970,2070,2110,1450,1800,1310,720,2080,3490,2210,1770,2140,1210,1290,1790,3400,2260,1820,3180,1330,3250,1670,1200,2180,1360,1250,3570,1450,3280,1430,2020,1230,1440,1360,2110,4110,1310,970,3330,1620,1690,2350,2750,1650,1970,1490,2080,1710,1640,2180,3780,1400,5730,1140,1500,1010,2880,2270,1840,1970,1370,2460,3220,930,2810,830,2810,2330,2010,1490,2100,1330,910,2060,800,2230,3270,3030,2420,890,1900,2100,1120,2340,2200,1540,2669,1890,2750,3530,2800,4090,1580,2260,740,1300,1480,1830,820,1890,2200,1890,3100,1520,800,2340,740,1000,1700,1490,2000,2810,520,700,3610,1590,3030,1900,1770,1940,1960,2670,1880,1340,970,1630,1710,1050,2210,1770,1330,4590,2450,3200,1670,1720,1480,1310,1120,2030,1950,3170,2130,2440,3090,5850,1330,710,1140,2070,1140,4510,2670,2640,1490,3090,1880,3330,2140,2710,1280,2120,2500,770,2350,970,1490,1960,2060,1130,3810,3010,1560,2580,1778,2580,1530,1420,2680,2440,1790,1200,1700,1170,2080,4180,2470,1950,1960,1410,2440,1650,2080,3010,2560,3090,5000,1870,3500,2670,1150,3770,2640,3400,1650,2770,2500,560,1010,2070,1650,3190,2040,1930,2320,1810,2050,1250,2920,1770,3000,2540,1200,3240,2190,2520,1870,1500,2090,1360,3980,1470,1650,3040,1390,4410,950,2690,930,1790,1320,3590,810,1870,1510,3190,1230,2410,1720,1170,1110,1190,1010,2410,1130,900,1960,1250,3880,1250,1830,2000,2440,2229,1560,1070,2530,1280,2670,2600,1410,2180,2430,1200,3000,1270,2010,2400,1930,3250,1300,1440,2960,6630,2080,2040,2570,1370,1870,2070,600,1300,1420,2930,2010,2210,2430,1120,1690,1160,1480,1130,3950,1040,2330,4190,1240,2970,2030,1390,2760,3590,1800,1430,2760,1920,1500,1630,1190,2330,1000,980,630,1780,2800,1510,2060,4320,1850,2410,2329,1190,1950,1160,2020,2980,1000,1920,1450,1790,1700,2150,1730,3230,2830,1010,4400,1590,2830,3990,1670,1420,3240,1330,4610,1400,2430,1830,1450,2060,1320,3380,1720,2350,1140,2680,1940,1370,4570,1270,2070,2490,2680,2120,1040,1410,2480,2740,1370,1170,1160,1430,3020,1260,2360,2300,3190,1960,2050,3420,2490,2490,1500,2080,2810,1390,2940,3220,2540,1180,1890,1670,1340,1510,1700,1960,2010,2190,1070,2270,3360,2010,1590,2420,4370,1910,1690,1140,1270,2170,1654,1500,2780,720,2900,1470,980,1570,5350,1880,2290,6300,680,2900,1340,2100,2540,770,1930,970,2930,1560,1490,2864,2010,1160,3350,1494,1140,2070,1340,2800,1440,12050,1350,2880,1730,1200,2070,2510,2450,2400,3140,2240,2100,1070,1040,2960,1200,2160,1760,1400,2720,1500,1840,2030,3030,4475,2140,2680,3060,2850,2560,2000,2120,2750,2270,2510,2270,2160,1840,1690,2200,3280,1060,1470,1410,5540,2140,930,5305,1270,860,2430,2090,2160,1860,2170,1950,1340,1790,1410,800,2020,2240,1730,1820,1940,2740,2420,1740,1740,1790,1610,1490,2360,4700,1920,2770,1410,2150,700,2740,1680,2560,2680,1730,3430,1330,1260,1060,2770,1460,1790,3230,1594,1600,1520,1830,920,1160,2770,590,2650,880,2510,7 ...

# %% [markdown]
# Gráfico mostrando o modelo e os valores reais (x= metragem, y= custo)

# %%
grafico1 = px.scatter(x = X_casas_treinamento.ravel(), y = y_casas_treinamento)
grafico2 = px.line(x = X_casas_treinamento.ravel(), y = previsoes)
grafico2.data[0].line.color = 'red'
grafico3 = go.Figure(data=grafico1.data + grafico2.data)
grafico3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="9c01a2e4-b93d-42bb-991e-ddebbbf81d52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c01a2e4-b93d-42bb-991e-ddebbbf81d52")) {                    Plotly.newPlot(                        "9c01a2e4-b93d-42bb-991e-ddebbbf81d52",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1390,1450,2860,1050,1240,1860,2070,2710,2030,1000,2730,1714,1310,1240,1070,1480,2120,1900,2410,1610,2420,2800,1620,1500,1270,1500,1810,2980,3190,2750,1780,2600,1680,1130,1330,1630,1430,1870,2120,1880,1200,2180,3190,2020,1590,1270,1720,1190,3010,1400,3010,2140,2490,1930,4580,2720,1520,1360,2410,1140,720,2780,1840,1550,1450,4050,2420,2730,3230,980,1240,2070,2320,1860,4010,2480,1270,990,1210,1930,1910,1730,2570,1050,1890,2050,2820,2970,2860,1500,1840,1420,520,4380,2680,670,3140,1530,2210,1580,5000,1220,4040,750,3100,1580,2260,1720,1280,930,970,2070,2110,1450,1800,1310,720,2080,3490,2210,1770,2140,1210,1290,1790,3400,2260,1820,3180,1330,3250,1670,1200,2180,1360,1250,3570,1450,3280,1430,2020,1230,1440,1360,2110,4110,1310,970,3330,1620,1690,2350,2750,1650,1970,1490,2080,1710,1640,2180,3780,1400,5730,1140,1500,1010,2880,2270,1840,1970,1370,2460,3220,930,2810,830,2810,2330,2010,1490,2100,1330,910,2060,800,2230,3270,3030,2420,890,1900,2100,1120,2340,2200,1540,2669,1890,2750,3530,2800,4090,1580,2260,740,1300,1480,1830,820,1890,2200,1890,3100,1520,800,2340,740,1000,1700,1490,2000,2810,520,700,3610,1590,3030,1900,1770,1940,1960,2670,1880,1340,970,1630,1710,1050,2210,1770,1330,4590,2450,3200,1670,1720,1480,1310,1120,2030,1950,3170,2130,2440,3090,5850,1330,710,1140,2070,1140,4510,2670,2640,1490,3090,1880,3330,2140,2710,1280,2120,2500,770,2350,970,1490,1960,2060,1130,3810,3010,1560,2580,1778,2580,1530,1420,2680,2440,1790,1200,1700,1170,2080,4180,2470,1950,1960,1410,2440,1650,2080,3010,2560,3090,5000,1870,3500,2670,1150,3770,2640,3400,1650,2770,2500,560,1010,2070,1650,3190,2040,1930,2320,1810,2050,1250,2920,1770,3000,2540,1200,3240,2190,2520,1870,1500,2090,1360,3980,1470,1650,3040,1390,4410,950,2690,930,1790,1320,3590,810,1870,1510,3190,1230,2410,1720,1170,1110,1190,1010,2410,1130,900,1960,1250,3880,1250,1830,2000,2440,2229,1560,1070,2530,1280,2670,2600,1410,2180,2430,1200,3000,1270,2010,2400,1930,3250,1300,1440,2960,6630,2080,2040,2570,1370,1870,2070,600,1300,1420,2930,2010,2210,2430,1120,1690,1160,1480,1130,3950,1040,2330,4190,1240,2970,2030,1390,2760,3590,1800,1430,2760,1920,1500,1630,1190,2330,1000,980,630,1780,2800,1510,2060,4320,1850,2410,2329,1190,1950,1160,2020,2980,1000,1920,1450,1790,1700,2150,1730,3230,2830,1010,4400,1590,2830,3990,1670,1420,3240,1330,4610,1400,2430,1830,1450,2060,1320,3380,1720,2350,1140,2680,1940,1370,4570,1270,2070,2490,2680,2120,1040,1410,2480,2740,1370,1170,1160,1430,3020,1260,2360,2300,3190,1960,2050,3420,2490,2490,1500,2080,2810,1390,2940,3220,2540,1180,1890,1670,1340,1510,1700,1960,2010,2190,1070,2270,3360,2010,1590,2420,4370,1910,1690,1140,1270,2170,1654,1500,2780,720,2900,1470,980,1570,5350,1880,2290,6300,680,2900,1340,2100,2540,770,1930,970,2930,1560,1490,2864,2010,1160,3350,1494,1140,2070,1340,2800,1440,12050,1350,2880,1730,1200,2070,2510,2450,2400,3140,2240,2100,1070,1040,2960,1200,2160,1760,1400,2720,1500,1840,2030,3030,4475,2140,2680,3060,2850,2560,2000,2120,2750,2270,2510,2270,2160,1840,1690,2200,3280,1060,1470,1410,5540,2140,930,5305,1270,860,2430,2090,2160,1860,2170,1950,1340,1790,1410,800,2020,2240,1730,1820,1940,2740,2420,1740,1740,1790,1610,1490,2360,4700,1920,2770,1410,2150,700,2740,1680,2560,2680,1730,3430,1330,1260,1060,2770,1460,1790,3230,1594,1600,1520,1830,920,1160,2770,590,2650,880,2510,7 ...

# %% [markdown]
# **Aplicando as métricas de avaliação:**

# %% [markdown]
# Previsão do algoritmo:

# %%
previsoes_teste = regressor_simples_casas.predict(X_casas_teste)
previsoes_teste
# Out:
# array([ 360116.30871034, 1261900.99358095,  362899.59477476, ...,
#         560512.90534826,  374032.73903242,  329500.16200177])

# %% [markdown]
# Valores reais:

# %%
y_casas_teste
# Out:
# array([ 297000., 1578000.,  562100., ...,  380000.,  268000.,  206000.])

# %% [markdown]
# Diferença entre a previsão do algoritmo e o valor real

# %% [markdown]
# Calcula o valor absoluto (desconsidera o negativo)

# %%
abs(y_casas_teste - previsoes_teste).mean()
# Out:
# 172604.1288999542

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# Valor do erro (bem grande nesse cenário)

# %% [markdown]
# Cálculo do MEA (mean absolute error)

# %%
mean_absolute_error(y_casas_teste, previsoes_teste)
# Out:
# 172604.1288999542

# %% [markdown]
# Cálculo do MSE (mean squared error)

# %%
mean_squared_error(y_casas_teste, previsoes_teste)
# Out:
# 70170013932.1159

# %% [markdown]
# Cálculo do SQRT

# %%
np.sqrt(mean_squared_error(y_casas_teste, previsoes_teste))
# Out:
# 264896.23238565685

# %% [markdown]
# Gerando o gráfico - base de dados de teste

# %%
grafico1 = px.scatter(x = X_casas_teste.ravel(), y = y_casas_teste)
grafico2 = px.line(x = X_casas_teste.ravel(), y = previsoes_teste)
grafico2.data[0].line.color = 'red'
grafico3 = go.Figure(data=grafico1.data + grafico2.data)
grafico3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="cfa2121b-e793-406d-9fea-12ed68d5abc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfa2121b-e793-406d-9fea-12ed68d5abc7")) {                    Plotly.newPlot(                        "cfa2121b-e793-406d-9fea-12ed68d5abc7",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1430,4670,1440,1130,3180,1650,1720,2538,2460,4460,2360,1720,1020,1340,3180,1220,1530,2130,930,1370,1670,2220,1900,1100,2370,1100,1530,1640,2110,1690,2070,2020,2560,3330,3070,1820,1260,2040,2600,1080,1180,1390,2410,2650,2350,2370,1870,3140,1550,3170,1420,2210,3200,1150,3510,1330,1530,2000,1280,2700,1250,2070,1350,3110,2840,3160,1640,2740,3460,1970,3672,1540,2110,1630,3190,4480,2610,3390,1680,2130,2010,2390,3910,2150,2070,2060,1550,1340,1750,1150,5584,2690,2390,2320,4810,1610,2080,2710,1530,2130,1200,2390,2500,4060,1700,2430,1940,2210,1120,1820,1920,3040,1010,3000,2490,3160,1600,1740,1660,3600,1847,1710,1160,3960,1230,1200,810,2080,950,950,2880,980,1140,1240,2140,1760,2740,1050,1370,2010,2800,1450,2590,1860,1310,2680,3000,1960,2040,1200,3720,2610,1290,2570,1370,2400,1590,3190,940,2150,1440,3410,2870,1840,1850,2170,1790,1820,2320,1090,1690,2000,3200,1090,2640,1160,1620,5550,860,1800,930,1220,2290,2410,750,1660,1320,4650,3410,2520,1770,820,2100,2340,2500,2390,1230,2250,1980,2230,1590,1650,1040,4060,1040,1190,3870,1520,3045,2250,1480,1880,1320,2240,1090,1870,1260,3150,3000,1640,1540,3290,2940,2100,1120,1270,1690,2760,1880,1270,2800,2700,2880,2290,1360,3030,810,2280,1890,1660,2940,3060,1970,1460,1370,1640,2590,1820,1660,2170,1550,1430,2660,1470,3350,2100,1380,2590,900,1040,2090,2230,850,1650,940,2820,2560,1030,2000,1820,1250,3110,3930,1780,1140,1240,640,2330,2330,880,2410,1730,2330,2260,4380,970,1790,930,1600,1553,2060,2180,2200,2980,1730,1670,2430,1870,1940,2020,1750,3210,1390,1700,3640,2780,1720,5150,1950,3970,1890,870,2330,2200,1090,2120,1160,1970,3160,1830,1360,2380,2730,2490,1780,2360,1440,1620,1870,1770,3750,4240,1550,3090,3560,1090,3640,1750,2660,820,1940,1350,2250,4830,940,1610,3480,1230,3840,2690,1060,1600,1750,3090,3420,2210,1750,1890,2030,1570,2160,2560,1080,1080,1190,1940,3500,1584,3180,2110,1450,2810,1830,2820,1880,820,1220,1680,2650,1920,2410,1770,2940,3100,1980,1384,880,1100,800,1710,1150,1570,2360,1980,2570,7440,1660,1840,2310,1890,950,2060,2400,890,2060,1130,1630,2301,1290,3290,1980,1480,1180,1100,1660,1677,2905,1150,1820,2240,1920,1880,880,3440,2820,1550,1150,2810,1840,3080,2560,920,680,1880,1720,2580,2140,2360,960,1400,1630,2430,1380,1610,3970,3110,3070,1940,2540,1600,1550,1600,3028,2020,3370,1500,2000,1570,3110,1210,3490,2080,2480,2210,1870,740,1680,1350,4370,1120,1480,2580,2190,1970,1340,1260,2300,1120,700,1700,2220,4530,1540,1180,1790,3740,1270,2900,1080,1450,1710,2190,1730,3420,7850,1620,2590,3090,2460,1530,2660,2150,1990,980,720,2640,1190,1130,1760,1370,2120,2230,3480,2850,1390,1440,1900,3210,2570,2310,4100,1710,2370,2590,1670,1850,2730,1530,1120,2140,3360,1570,860,1060,1010,3160,3230,1890,2190,2370,2130,2750,2700,1560,1590,2420,3250,1620,5860,1384,2030,2850,1460,1520,2490,1580,1720,1620,1810,1540,1860,2740,2390,1690,2690,1740,2200,2270,1740,1700,4610,2310,2400,2600,2270,1010,750,1220,2030,2100,3860,2320,1640,1560,2820,2320,3690,2478,1460,1440,3720,1360,2330,1790,2250,1820,2150,1730,1150,3030,820,1550,4750,3500,1530,1150,1720,1560,1870,2810,1370,1660,1640,1580,4570,1270,1170,1240,2710,2010,1450,3920,1340,1650,1170,1090,1390,1570,2990,1130,2500,950,1870,2250,1880,1580,1610,3130,1900,1760,1450,2849,3060,1470,4660,3410,950,2130,1720,1600,2650,2480,2520,1830,1680,1050,3070,1340,1950,2140,2210,3370,1220,1980,2440,1 ...

# %% [markdown]
# O comportamento do gráfico de teste é muito semelhante ao comportamento de treinamento.

# %% [markdown]
# # Regressão linear múltipla

# %% [markdown]
# ## Base preço das casas - MAE 123.888, 0.68

# %%
base_casas = pd.read_csv('house_prices.csv')

# %%
base_casas
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
X_casas = base_casas.iloc[:, 3:19].values
X_casas
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03, ...,  9.81780e+04,
#          4.75112e+01, -1.22257e+02],
#        [ 3.00000e+00,  2.25000e+00,  2.57000e+03, ...,  9.81250e+04,
#          4.77210e+01, -1.22319e+02],
#        [ 2.00000e+00,  1.00000e+00,  7.70000e+02, ...,  9.80280e+04,
#          4.77379e+01, -1.22233e+02],
#        ...,
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75944e+01, -1.22299e+02],
#        [ 3.00000e+00,  2.50000e+00,  1.60000e+03, ...,  9.80270e+04,
#          4.75345e+01, -1.22069e+02],
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75941e+01, -1.22299e+02]])

# %%
y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size = 0.3, random_state = 0)

# %% [markdown]
# Treinamento (15129, 16) e teste (6484, 16)

# %%
X_casas_treinamento.shape, X_casas_teste.shape
# Out:
# ((15129, 16), (6484, 16))

# %% [markdown]
# Treinamento: Encontra o parâmetro B0

# %%
regressor_multiplo_casas = LinearRegression()
regressor_multiplo_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
regressor_multiplo_casas.intercept_
# Out:
# 5736222.703394298

# %% [markdown]
# Coeficientes: B1 (cada atributo previsor tem o seu próprio coeficiente) - Fórmula da regressão linear múltipla (um atributo para cada coeficiente)

# %%
regressor_multiplo_casas.coef_
# Out:
# array([-3.08423090e+04,  3.66540816e+04,  1.12179159e+02,  8.00604120e-03,
#         9.60355724e+03,  5.85441638e+05,  5.60621840e+04,  2.54795004e+04,
#         1.01092121e+05,  6.96565321e+01,  4.25226266e+01, -2.60724691e+03,
#         1.40070753e+01, -5.53557431e+02,  6.11778251e+05, -1.95564688e+05])

# %%
len(regressor_multiplo_casas.coef_)
# Out:
# 16

# %% [markdown]
# O valor da regressão múltipla (que utilizou mais atributos) de 0,7 é maior do que o valor da regressão linear (0,4). Idem teste.

# %%
regressor_multiplo_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.7029888085955007

# %%
regressor_multiplo_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.6885414149062676

# %%
previsoes = regressor_multiplo_casas.predict(X_casas_teste)
previsoes
# Out:
# array([ 383751.77768699, 1514216.17517446,  546921.96179113, ...,
#         314968.57623303,  219405.55573556,  148128.83467043])

# %%
y_casas_teste
# Out:
# array([ 297000., 1578000.,  562100., ...,  380000.,  268000.,  206000.])

# %% [markdown]
# Erro absoluto (a regressão múltipla apresenta um erro menor que a regressão linear simples, neste caso)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 123888.4437748578

# %% [markdown]
# # Regressão polinomial

# %% [markdown]
# ## Base plano de saúde

# %%
base_plano_saude2 = pd.read_csv('plano_saude2.csv')
base_plano_saude2
# Out:
#    idade  custo
# 0     18    470
# 1     23    520
# 2     28    630
# 3     33    830
# 4     38   1150
# 5     43   1530
# 6     48   2040
# 7     53   3080
# 8     58   5100
# 9     63  10100

# %%
X_plano_saude2 = base_plano_saude2.iloc[:, 0:1].values
y_plano_saude2 = base_plano_saude2.iloc[:, 1].values

# %% [markdown]
# Coluna: atributo idade

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %% [markdown]
# Objetivo: Custo ($)

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %% [markdown]
# degree = 4 (eleva na quarta potência)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 4)
X_plano_saude2_poly = poly.fit_transform(X_plano_saude2)

# %%
X_plano_saude2_poly.shape
# Out:
# (10, 5)

# %%
18 * 18, 18 * 18 * 18, 18 * 18 * 18 * 18
# Out:
# (324, 5832, 104976)

# %%
X_plano_saude2_poly[0]
# Out:
# array([1.00000e+00, 1.80000e+01, 3.24000e+02, 5.83200e+03, 1.04976e+05])

# %%
23 * 23
# Out:
# 529

# %%
X_plano_saude2_poly[1]
# Out:
# array([1.00000e+00, 2.30000e+01, 5.29000e+02, 1.21670e+04, 2.79841e+05])

# %% [markdown]
# Base de dados final que vai para  a regressão

# %%
X_plano_saude2_poly
# Out:
# array([[1.0000000e+00, 1.8000000e+01, 3.2400000e+02, 5.8320000e+03,
#         1.0497600e+05],
#        [1.0000000e+00, 2.3000000e+01, 5.2900000e+02, 1.2167000e+04,
#         2.7984100e+05],
#        [1.0000000e+00, 2.8000000e+01, 7.8400000e+02, 2.1952000e+04,
#         6.1465600e+05],
#        [1.0000000e+00, 3.3000000e+01, 1.0890000e+03, 3.5937000e+04,
#         1.1859210e+06],
#        [1.0000000e+00, 3.8000000e+01, 1.4440000e+03, 5.4872000e+04,
#         2.0851360e+06],
#        [1.0000000e+00, 4.3000000e+01, 1.8490000e+03, 7.9507000e+04,
#         3.4188010e+06],
#        [1.0000000e+00, 4.8000000e+01, 2.3040000e+03, 1.1059200e+05,
#         5.3084160e+06],
#        [1.0000000e+00, 5.3000000e+01, 2.8090000e+03, 1.4887700e+05,
#         7.8904810e+06],
#        [1.0000000e+00, 5.8000000e+01, 3.3640000e+03, 1.9511200e+05,
#         1.1316496e+07],
#        [1.0000000e+00, 6.3000000e+01, 3.9690000e+03, 2.5004700e+05,
#         1.5752961e+07]])

# %%
regressor_saude_polinomial = LinearRegression()
regressor_saude_polinomial.fit(X_plano_saude2_poly, y_plano_saude2)
# Out:
# LinearRegression()

# %%
# b0
regressor_saude_polinomial.intercept_
# Out:
# 16561.97463791193

# %%
# b1 (n)
regressor_saude_polinomial.coef_
# Out:
# array([ 0.00000000e+00, -2.12242253e+03,  9.90404199e+01, -1.95058276e+00,
#         1.40792541e-02])

# %%
novo = [[40]]

# %%
novo = poly.transform(novo)
novo
# Out:
# array([[1.00e+00, 4.00e+01, 1.60e+03, 6.40e+04, 2.56e+06]])

# %% [markdown]
# Interpretação: A previsão do custo do plano de saúde para uma pessoa de 40 anos é 1335.33

# %%
regressor_saude_polinomial.predict(novo)
# Out:
# array([1335.33958015])

# %% [markdown]
# Previsões para todas as idades da base
#        [18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]

# %%
previsoes = regressor_saude_polinomial.predict(X_plano_saude2_poly)
previsoes
# Out:
# array([ 549.65035464,  345.85081575,  616.53845992,  975.8391595 ,
#        1249.06759853, 1472.7272727 , 1894.51048941, 2973.2983677 ,
#        5379.16083828, 9993.35664357])

# %% [markdown]
# Gráfico da regressão polinomial (a linha vermelha é o modelo de previsão da regressão polinomial)

# %%
grafico = px.scatter(x = X_plano_saude2[:,0], y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2[:,0], y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="ee7edc3b-c898-4cf8-9e62-63d9e40fa306" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee7edc3b-c898-4cf8-9e62-63d9e40fa306")) {                    Plotly.newPlot(                        "ee7edc3b-c898-4cf8-9e62-63d9e40fa306",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[549.6503546413369,345.8508157539454,616.5384599200042,975.8391594997884,1249.0675985260023,1472.727272703698,1894.5104894104443,2973.2983676960575,5379.160838282856,9993.356643565625],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoord ...

# %% [markdown]
# ## Base preço das casas - MAE 101.225, 0.81

# %% [markdown]
# Regressão polinomial - base preços_casas

# %% [markdown]
# Treinamento

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %% [markdown]
# Teste

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
X_casas_treinamento_poly = poly.fit_transform(X_casas_treinamento)
X_casas_teste_poly = poly.transform(X_casas_teste)

# %%
X_casas_treinamento_poly.shape, X_casas_teste_poly.shape
# Out:
# ((15129, 153), (6484, 153))

# %% [markdown]
# Regressor - treinamento -

# %%
regressor_casas_poly = LinearRegression()
regressor_casas_poly.fit(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
regressor_casas_poly.score(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# 0.817937209116416

# %% [markdown]
# Regressor - teste

# %%
regressor_casas_poly.score(X_casas_teste_poly, y_casas_teste)
# Out:
# 0.8153249436575213

# %% [markdown]
# Gerando as previsões

# %%
previsoes = regressor_casas_poly.predict(X_casas_teste_poly)
previsoes
# Out:
# array([ 386279.00622559, 1991142.84359741,  579098.07328033, ...,
#         432859.80838776,  234193.23797607,  123839.61456299])

# %% [markdown]
# Comparativo da previsão com os dados reais

# %%
y_casas_teste
# Out:
# array([ 297000., 1578000.,  562100., ...,  380000.,  268000.,  206000.])

# %% [markdown]
# Erro: Melhorou em relação a regressão linear simples

# %%
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 101225.53413948139

# %% [markdown]
# # Árvores de decisão

# %% [markdown]
# ## Base plano saúde

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
base_plano_saude2 = pd.read_csv('plano_saude2.csv')
base_plano_saude2
# Out:
#    idade  custo
# 0     18    470
# 1     23    520
# 2     28    630
# 3     33    830
# 4     38   1150
# 5     43   1530
# 6     48   2040
# 7     53   3080
# 8     58   5100
# 9     63  10100

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.tree import DecisionTreeRegressor
regressor_arvore_saude = DecisionTreeRegressor()
regressor_arvore_saude.fit(X_plano_saude2, y_plano_saude2)
# Out:
# DecisionTreeRegressor()

# %%
previsoes = regressor_arvore_saude.predict(X_plano_saude2)
previsoes
# Out:
# array([  470.,   520.,   630.,   830.,  1150.,  1530.,  2040.,  3080.,
#         5100., 10100.])

# %%
regressor_arvore_saude.score(X_plano_saude2, y_plano_saude2)
# Out:
# 1.0

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = previsoes, name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="b5997ef5-de72-4434-973d-c2493baa150c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5997ef5-de72-4434-973d-c2493baa150c")) {                    Plotly.newPlot(                        "b5997ef5-de72-4434-973d-c2493baa150c",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[470.0,520.0,630.0,830.0,1150.0,1530.0,2040.0,3080.0,5100.0,10100.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}] ...

# %%
X_teste_arvore = np.arange(min(X_plano_saude2), max(X_plano_saude2), 0.1)
X_teste_arvore
# Out:
# array([18. , 18.1, 18.2, 18.3, 18.4, 18.5, 18.6, 18.7, 18.8, 18.9, 19. ,
#        19.1, 19.2, 19.3, 19.4, 19.5, 19.6, 19.7, 19.8, 19.9, 20. , 20.1,
#        20.2, 20.3, 20.4, 20.5, 20.6, 20.7, 20.8, 20.9, 21. , 21.1, 21.2,
#        21.3, 21.4, 21.5, 21.6, 21.7, 21.8, 21.9, 22. , 22.1, 22.2, 22.3,
#        22.4, 22.5, 22.6, 22.7, 22.8, 22.9, 23. , 23.1, 23.2, 23.3, 23.4,
#        23.5, 23.6, 23.7, 23.8, 23.9, 24. , 24.1, 24.2, 24.3, 24.4, 24.5,
#        24.6, 24.7, 24.8, 24.9, 25. , 25.1, 25.2, 25.3, 25.4, 25.5, 25.6,
#        25.7, 25.8, 25.9, 26. , 26.1, 26.2, 26.3, 26.4, 26.5, 26.6, 26.7,
#        26.8, 26.9, 27. , 27.1, 27.2, 27.3, 27.4, 27.5, 27.6, 27.7, 27.8,
#        27.9, 28. , 28.1, 28.2, 28.3, 28.4, 28.5, 28.6, 28.7, 28.8, 28.9,
#        29. , 29.1, 29.2, 29.3, 29.4, 29.5, 29.6, 29.7, 29.8, 29.9, 30. ,
#        30.1, 30.2, 30.3, 30.4, 30.5, 30.6, 30.7, 30.8, 30.9, 31. , 31.1,
#        31.2, 31.3, 31.4, 31.5, 31.6, 31.7, 31.8, 31.9, 32. , 32.1, 32.2,
#        32.3, 32.4, 32.5, 32.6, 32.7, 32.8, 32.9, 33. , 33.1, 33.2, 33.3,
#        33.4, 33.5, 33.6, 33.7, 33.8, 33.9, 34. , 34.1, 34.2, 34.3, 34.4,
#        34.5, 34.6, 34.7, 34.8, 34.9, 35. , 35.1, 35.2, 35.3, 35.4, 35.5,
#        35.6, 35.7, 35.8, 35.9, 36. , 36.1, 36.2, 36.3, 36.4, 36.5, 36.6,
#        36.7, 36.8, 36.9, 37. , 37.1, 37.2, 37.3, 37.4, 37.5, 37.6, 37.7,
#        37.8, 37.9, 38. , 38.1, 38.2, 38.3, 38.4, 38.5, 38.6, 38.7, 38.8,
#        38.9, 39. , 39.1, 39.2, 39.3, 39.4, 39.5, 39.6, 39.7, 39.8, 39.9,
#        40. , 40.1, 40.2, 40.3, 40.4, 40.5, 40.6, 40.7, 40.8, 40.9, 41. ,
#        41.1, 41.2, 41.3, 41.4, 41.5, 41.6, 41.7, 41.8, 41.9, 42. , 42.1,
#        42.2, 42.3, 42.4, 42.5, 42.6, 42.7, 42.8, 42.9, 43. , 43.1, 43.2,
#        43.3, 43.4, 43.5, 43.6, 43.7, 43.8, 43.9, 44. , 44.1, 44.2, 44.3,
#        44.4, 44.5, 44.6, 44.7, 44.8, 44.9, 45. , 45.1, 45.2, 45.3, 45.4,
#        45.5, 45.6, 45.7, 45.8, 45.9, 46. , 46.1, 46.2, 46.3, 46.4, 46.5,
#        46.6, 46.7, 46.8, 46.9, 47. , 47.1, 47.2, 47.3, 47.4, 47.5, 47.6,
#        47.7, 47.8, 47.9, 48. , 48.1, 48.2, 48.3, 48.4, 48.5, 48.6, 48.7,
#        48.8, 48.9, 49. , 49.1, 49.2, 49.3, 49.4, 49.5, 49.6, 49.7, 49.8,
#        49.9, 50. , 50.1, 50.2, 50.3, 50.4, 50.5, 50.6, 50.7, 50.8, 50.9,
#        51. , 51.1, 51.2, 51.3, 51.4, 51.5, 51.6, 51.7, 51.8, 51.9, 52. ,
#        52.1, 52.2, 52.3, 52.4, 52.5, 52.6, 52.7, 52.8, 52.9, 53. , 53.1,
#        53.2, 53.3, 53.4, 53.5, 53.6, 53.7, 53.8, 53.9, 54. , 54.1, 54.2,
#        54.3, 54.4, 54.5, 54.6, 54.7, 54.8, 54.9, 55. , 55.1, 55.2, 55.3,
#        55.4, 55.5, 55.6, 55.7, 55.8, 55.9, 56. , 56.1, 56.2, 56.3, 56.4,
#        56.5, 56.6, 56.7, 56.8, 56.9, 57. , 57.1, 57.2, 57.3, 57.4, 57.5,
#        57.6, 57.7, 57.8, 57.9, 58. , 58.1, 58.2, 58.3, 58.4, 58.5, 58.6,
#        58.7, 58.8, 58.9, 59. , 59.1, 59.2, 59.3, 59.4, 59.5, 59.6, 59.7,
#        59.8, 59.9, 60. , 60.1, 60.2, 60.3, 60.4, 60.5, 60.6, 60.7, 60.8,
#        60.9, 61. , 61.1, 61.2, 61.3, 61.4, 61.5, 61.6, 61.7, 61.8, 61.9,
#        62. , 62.1, 62.2, 62.3, 62.4, 62.5, 62.6, 62.7, 62.8, 62.9])

# %%
X_teste_arvore.shape
# Out:
# (450,)

# %%
X_teste_arvore = X_teste_arvore.reshape(-1,1)
X_teste_arvore.shape
# Out:
# (450, 1)

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_teste_arvore.ravel(), y = regressor_arvore_saude.predict(X_teste_arvore), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="c87f3d12-7ae0-4681-905b-a636f0caba9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c87f3d12-7ae0-4681-905b-a636f0caba9f")) {                    Plotly.newPlot(                        "c87f3d12-7ae0-4681-905b-a636f0caba9f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18.0,18.1,18.200000000000003,18.300000000000004,18.400000000000006,18.500000000000007,18.60000000000001,18.70000000000001,18.80000000000001,18.900000000000013,19.000000000000014,19.100000000000016,19.200000000000017,19.30000000000002,19.40000000000002,19.50000000000002,19.600000000000023,19.700000000000024,19.800000000000026,19.900000000000027,20.00000000000003,20.10000000000003,20.20000000000003,20.300000000000033,20.400000000000034,20.500000000000036,20.600000000000037,20.70000000000004,20.80000000000004,20.90000000000004,21.000000000000043,21.100000000000044,21.200000000000045,21.300000000000047,21.40000000000005,21.50000000000005,21.60000000000005,21.700000000000053,21.800000000000054,21.900000000000055,22.000000000000057,22.10000000000006,22.20000000000006,22.30000000000006,22.400000000000063,22.500000000000064,22.600000000000065,22.700000000000067,22.800000000000068,22.90000000000007,23.00000000000007,23.100000000000072,23.200000000000074,23.300000000000075,23.400000000000077,23.500000000000078,23.60000000000008,23.70000000000008,23.800000000000082,23.900000000000084,24.000000000000085,24.100000000000087,24.200000000000088,24.30000000000009,24.40000000000009,24.500000000000092,24.600000000000094,24.700000000000095,24.800000000000097,24.900000000000098,25.0000000000001,25.1000000000001,25.200000000000102,25.300000000000104,25.400000000000105,25.500000000000107,25.600000000000108,25.70000000000011,25.80000000000011,25.900000000000112,26.000000000000114,26.100000000000115,26.200000000000117,26.300000000000118,26.40000000000012,26.50000000000012,26.600000000000122,26.700000000000124,26.800000000000125,26.900000000000126,27.000000000000128,27.10000000000013,27.20000000000013,27.300000000000132,27.400000000000134,27.500000000000135,27.600000000000136,27.700000000000138,27.80000000000014,27.90000000000014,28.000000000000142,28.100000000000144,28.200000000000145,28.300000000000146,28.400000000000148,28.50000000000015,28.60000000000015,28.700000000000152,28.800000000000153,28.900000000000155,29.000000000000156,29.100000000000158,29.20000000000016,29.30000000000016,29.400000000000162,29.500000000000163,29.600000000000165,29.700000000000166,29.800000000000168,29.90000000000017,30.00000000000017,30.100000000000172,30.200000000000173,30.300000000000175,30.400000000000176,30.500000000000178,30.60000000000018,30.70000000000018,30.800000000000182,30.900000000000183,31.000000000000185,31.100000000000186,31.200000000000188,31.30000000000019,31.40000000000019,31.500000000000192,31.600000000000193,31.700000000000195,31.800000000000196,31.900000000000198,32.0000000000002,32.1000000000002,32.2000000000002,32.3000000000002,32.400000000000205,32.500000000000206,32.60000000000021,32.70000000000021,32.80000000000021,32.90000000000021,33.00000000000021,33.100000000000215,33.200000000000216,33.30000000000022,33.40000000000022,33.50000000000022,33.60000000000022,33.70000000000022,33.800000000000225,33.900000000000226,34.00000000000023,34.10000000000023,34.20000000000023,34.30000000000023,34.40000000000023,34.500000000000234,34.600000000000236,34.70000000000024,34.80000000000024,3 ...

# %%
regressor_arvore_saude.predict([[40.6]])
# Out:
# array([1530.])

# %% [markdown]
# ## Base preço das casas - MAE 99.917, 0.73

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 4.00000e+00,  1.50000e+00,  1.39000e+03, ...,  9.81330e+04,
#          4.77224e+01, -1.22332e+02],
#        [ 3.00000e+00,  1.50000e+00,  1.45000e+03, ...,  9.81330e+04,
#          4.77725e+01, -1.22349e+02],
#        [ 5.00000e+00,  2.75000e+00,  2.86000e+03, ...,  9.80520e+04,
#          4.77082e+01, -1.22104e+02],
#        ...,
#        [ 3.00000e+00,  2.25000e+00,  2.36000e+03, ...,  9.80420e+04,
#          4.73856e+01, -1.22158e+02],
#        [ 4.00000e+00,  2.00000e+00,  2.37000e+03, ...,  9.80010e+04,
#          4.72831e+01, -1.22279e+02],
#        [ 4.00000e+00,  2.25000e+00,  2.38000e+03, ...,  9.80080e+04,
#          4.76126e+01, -1.22120e+02]])

# %%
y_casas_treinamento
# Out:
# array([400000., 430000., 720000., ..., 431000., 411000., 699900.])

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
regressor_arvore_casas = DecisionTreeRegressor()
regressor_arvore_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# DecisionTreeRegressor()

# %%
regressor_arvore_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.9992712177726063

# %%
regressor_arvore_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.7343095387423245

# %%
previsoes = regressor_arvore_casas.predict(X_casas_teste)
previsoes
# Out:
# array([ 288000., 1980000.,  507000., ...,  289000.,  215000.,  218000.])

# %%
y_casas_teste
# Out:
# array([ 297000., 1578000.,  562100., ...,  380000.,  268000.,  206000.])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 100245.87469154842

# %% [markdown]
# # Random forest

# %% [markdown]
# ## Base plano de saúde

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_random_forest_saude = RandomForestRegressor(n_estimators = 10)
regressor_random_forest_saude.fit(X_plano_saude2, y_plano_saude2)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
regressor_random_forest_saude.score(X_plano_saude2, y_plano_saude2)
# Out:
# 0.9793791686577203

# %%
X_teste_arvore
# Out:
# array([[18. ],
#        [18.1],
#        [18.2],
#        [18.3],
#        [18.4],
#        [18.5],
#        [18.6],
#        [18.7],
#        [18.8],
#        [18.9],
#        [19. ],
#        [19.1],
#        [19.2],
#        [19.3],
#        [19.4],
#        [19.5],
#        [19.6],
#        [19.7],
#        [19.8],
#        [19.9],
#        [20. ],
#        [20.1],
#        [20.2],
#        [20.3],
#        [20.4],
#        [20.5],
#        [20.6],
#        [20.7],
#        [20.8],
#        [20.9],
#        [21. ],
#        [21.1],
#        [21.2],
#        [21.3],
#        [21.4],
#        [21.5],
#        [21.6],
#        [21.7],
#        [21.8],
#        [21.9],
#        [22. ],
#        [22.1],
#        [22.2],
#        [22.3],
#        [22.4],
#        [22.5],
#        [22.6],
#        [22.7],
#        [22.8],
#        [22.9],
#        [23. ],
#        [23.1],
#        [23.2],
#        [23.3],
#        [23.4],
#        [23.5],
#        [23.6],
#        [23.7],
#        [23.8],
#        [23.9],
#        [24. ],
#        [24.1],
#        [24.2],
#        [24.3],
#        [24.4],
#        [24.5],
#        [24.6],
#        [24.7],
#        [24.8],
#        [24.9],
#        [25. ],
#        [25.1],
#        [25.2],
#        [25.3],
#        [25.4],
#        [25.5],
#        [25.6],
#        [25.7],
#        [25.8],
#        [25.9],
#        [26. ],
#        [26.1],
#        [26.2],
#        [26.3],
#        [26.4],
#        [26.5],
#        [26.6],
#        [26.7],
#        [26.8],
#        [26.9],
#        [27. ],
#        [27.1],
#        [27.2],
#        [27.3],
#        [27.4],
#        [27.5],
#        [27.6],
#        [27.7],
#        [27.8],
#        [27.9],
#        [28. ],
#        [28.1],
#        [28.2],
#        [28.3],
#        [28.4],
#        [28.5],
#        [28.6],
#        [28.7],
#        [28.8],
#        [28.9],
#        [29. ],
#        [29.1],
#        [29.2],
#        [29.3],
#        [29.4],
#        [29.5],
#        [29.6],
#        [29.7],
#        [29.8],
#        [29.9],
#        [30. ],
#        [30.1],
#        [30.2],
#        [30.3],
#        [30.4],
#        [30.5],
#        [30.6],
#        [30.7],
#        [30.8],
#        [30.9],
#        [31. ],
#        [31.1],
#        [31.2],
#        [31.3],
#        [31.4],
#        [31.5],
#        [31.6],
#        [31.7],
#        [31.8],
#        [31.9],
#        [32. ],
#        [32.1],
#        [32.2],
#        [32.3],
#        [32.4],
#        [32.5],
#        [32.6],
#        [32.7],
#        [32.8],
#        [32.9],
#        [33. ],
#        [33.1],
#        [33.2],
#        [33.3],
#        [33.4],
#        [33.5],
#        [33.6],
#        [33.7],
#        [33.8],
#        [33.9],
#        [34. ],
#        [34.1],
#        [34.2],
#        [34.3],
#        [34.4],
#        [34.5],
#        [34.6],
#        [34.7],
#        [34.8],
#        [34.9],
#        [35. ],
#        [35.1],
#        [35.2],
#        [35.3],
#        [35.4],
#        [35.5],
#        [35.6],
#        [35.7],
#        [35.8],
#        [35.9],
#        [36. ],
#        [36.1],
#        [36.2],
#        [36.3],
#        [36.4],
#        [36.5],
#        [36.6],
#        [36.7],
#        [36.8],
#        [36.9],
#        [37. ],
#        [37.1],
#        [37.2],
#        [37.3],
#        [37.4],
#        [37.5],
#        [37.6],
#        [37.7],
#        [37.8],
#        [37.9],
#        [38. ],
#        [38.1],
#        [38.2],
#        [38.3],
#        [38.4],
#        [38.5],
#        [38.6],
#        [38.7],
#        [38.8],
#        [38.9],
#        [39. ],
#        [39.1],
#        [39.2],
#        [39.3],
#        [39.4],
#        [39.5],
#        [39.6],
#        [39.7],
#        [39.8],
#        [39.9],
#        [40. ],
#        [40.1],
#        [40.2],
#        [40.3],
#        [40.4],
#        [40.5],
#        [40.6],
#        [40.7],
#        [40.8],
#        [40.9],
#        [41. ],
#        [41.1],
#        [41.2],
#        [41.3],
#        [41.4],
#        [41.5],
#        [41.6],
#        [41.7],
#        [41.8],
#        [41.9],
#        [42. ],
#        [42.1],
#        [42.2],
#        [42.3],
#        [42.4],
#        [42.5],
#        [42.6],
#        [42.7],
#        [42.8],
#        [42.9],
#        [43. ],
#        [43.1],
#        [43.2],
#        [43.3],
#        [43.4],
#        [43.5],
#        [43.6],
#        [43.7],
#        [43.8],
#        [43.9],
#        [44. ],
#        [44.1],
#        [44.2],
#        [44.3],
#        [44.4],
#        [44.5],
#        [44.6],
#        [44.7],
#        [44.8],
#        [44.9],
#        [45. ],
#        [45.1],
#        [45.2],
#        [45.3],
#        [45.4],
#        [45.5],
#        [45.6],
#        [45.7],
#        [45.8],
#        [45.9],
#        [46. ],
#        [46.1],
#        [46.2],
#        [46.3],
#        [46.4],
#        [46.5],
#        [46.6],
#        [46.7],
#        [46.8],
#        [46.9],
#        [47. ],
#        [47.1],
#        [47.2],
#        [47.3],
#        [47.4],
#        [47.5],
#        [47.6],
#        [47.7],
#        [47.8],
#        [47.9],
#        [48. ],
#        [48.1],
#        [48.2],
#        [48.3],
#        [48.4],
#        [48.5],
#        [48.6],
#        [48.7],
#        [48.8],
#        [48.9],
#        [49. ],
#        [49.1],
#        [49.2],
#        [49.3],
#        [49.4],
#        [49.5],
#        [49.6],
#        [49.7],
#        [49.8],
#        [49.9],
#        [50. ],
#        [50.1],
#        [50.2],
#        [50.3],
#        [50.4],
#        [50.5],
#        [50.6],
#        [50.7],
#        [50.8],
#        [50.9],
#        [51. ],
#        [51.1],
#        [51.2],
#        [51.3],
#        [51.4],
#        [51.5],
#        [51.6],
#        [51.7],
#        [51.8],
#        [51.9],
#        [52. ],
#        [52.1],
#        [52.2],
#        [52.3],
#        [52.4],
#        [52.5],
#        [52.6],
#        [52.7],
#        [52.8],
#        [52.9],
#        [53. ],
#        [53.1],
#        [53.2],
#        [53.3],
#        [53.4],
#        [53.5],
#        [53.6],
#        [53.7],
#        [53.8],
#        [53.9],
#        [54. ],
#        [54.1],
#        [54.2],
#        [54.3],
#        [54.4],
#        [54.5],
#        [54.6],
#        [54.7],
#        [54.8],
#        [54.9],
#        [55. ],
#        [55.1],
#        [55.2],
#        [55.3],
#        [55.4],
#        [55.5],
#        [55.6],
#        [55.7],
#        [55.8],
#        [55.9],
#        [56. ],
#        [56.1],
#        [56.2],
#        [56.3],
#        [56.4],
#        [56.5],
#        [56.6],
#        [56.7],
#        [56.8],
#        [56.9],
#        [57. ],
#        [57.1],
#        [57.2],
#        [57.3],
#        [57.4],
#        [57.5],
#        [57.6],
#        [57.7],
#        [57.8],
#        [57.9],
#        [58. ],
#        [58.1],
#        [58.2],
#        [58.3],
#        [58.4],
#        [58.5],
#        [58.6],
#        [58.7],
#        [58.8],
#        [58.9],
#        [59. ],
#        [59.1],
#        [59.2],
#        [59.3],
#        [59.4],
#        [59.5],
#        [59.6],
#        [59.7],
#        [59.8],
#        [59.9],
#        [60. ],
#        [60.1],
#        [60.2],
#        [60.3],
#        [60.4],
#        [60.5],
#        [60.6],
#        [60.7],
#        [60.8],
#        [60.9],
#        [61. ],
#        [61.1],
#        [61.2],
#        [61.3],
#        [61.4],
#        [61.5],
#        [61.6],
#        [61.7],
#        [61.8],
#        [61.9],
#        [62. ],
#        [62.1],
#        [62.2],
#        [62.3],
#        [62.4],
#        [62.5],
#        [62.6],
#        [62.7],
#        [62.8],
#        [62.9]])

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_teste_arvore.ravel(), y = regressor_random_forest_saude.predict(X_teste_arvore), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="95a27d78-9427-4408-901a-8d8997fe59fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95a27d78-9427-4408-901a-8d8997fe59fa")) {                    Plotly.newPlot(                        "95a27d78-9427-4408-901a-8d8997fe59fa",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18.0,18.1,18.200000000000003,18.300000000000004,18.400000000000006,18.500000000000007,18.60000000000001,18.70000000000001,18.80000000000001,18.900000000000013,19.000000000000014,19.100000000000016,19.200000000000017,19.30000000000002,19.40000000000002,19.50000000000002,19.600000000000023,19.700000000000024,19.800000000000026,19.900000000000027,20.00000000000003,20.10000000000003,20.20000000000003,20.300000000000033,20.400000000000034,20.500000000000036,20.600000000000037,20.70000000000004,20.80000000000004,20.90000000000004,21.000000000000043,21.100000000000044,21.200000000000045,21.300000000000047,21.40000000000005,21.50000000000005,21.60000000000005,21.700000000000053,21.800000000000054,21.900000000000055,22.000000000000057,22.10000000000006,22.20000000000006,22.30000000000006,22.400000000000063,22.500000000000064,22.600000000000065,22.700000000000067,22.800000000000068,22.90000000000007,23.00000000000007,23.100000000000072,23.200000000000074,23.300000000000075,23.400000000000077,23.500000000000078,23.60000000000008,23.70000000000008,23.800000000000082,23.900000000000084,24.000000000000085,24.100000000000087,24.200000000000088,24.30000000000009,24.40000000000009,24.500000000000092,24.600000000000094,24.700000000000095,24.800000000000097,24.900000000000098,25.0000000000001,25.1000000000001,25.200000000000102,25.300000000000104,25.400000000000105,25.500000000000107,25.600000000000108,25.70000000000011,25.80000000000011,25.900000000000112,26.000000000000114,26.100000000000115,26.200000000000117,26.300000000000118,26.40000000000012,26.50000000000012,26.600000000000122,26.700000000000124,26.800000000000125,26.900000000000126,27.000000000000128,27.10000000000013,27.20000000000013,27.300000000000132,27.400000000000134,27.500000000000135,27.600000000000136,27.700000000000138,27.80000000000014,27.90000000000014,28.000000000000142,28.100000000000144,28.200000000000145,28.300000000000146,28.400000000000148,28.50000000000015,28.60000000000015,28.700000000000152,28.800000000000153,28.900000000000155,29.000000000000156,29.100000000000158,29.20000000000016,29.30000000000016,29.400000000000162,29.500000000000163,29.600000000000165,29.700000000000166,29.800000000000168,29.90000000000017,30.00000000000017,30.100000000000172,30.200000000000173,30.300000000000175,30.400000000000176,30.500000000000178,30.60000000000018,30.70000000000018,30.800000000000182,30.900000000000183,31.000000000000185,31.100000000000186,31.200000000000188,31.30000000000019,31.40000000000019,31.500000000000192,31.600000000000193,31.700000000000195,31.800000000000196,31.900000000000198,32.0000000000002,32.1000000000002,32.2000000000002,32.3000000000002,32.400000000000205,32.500000000000206,32.60000000000021,32.70000000000021,32.80000000000021,32.90000000000021,33.00000000000021,33.100000000000215,33.200000000000216,33.30000000000022,33.40000000000022,33.50000000000022,33.60000000000022,33.70000000000022,33.800000000000225,33.900000000000226,34.00000000000023,34.10000000000023,34.20000000000023,34.30000000000023,34.40000000000023,34.500000000000234,34.600000000000236,34.70000000000024,34.80000000000024,3 ...

# %%
regressor_random_forest_saude.predict([[40]])
# Out:
# array([1353.])

# %% [markdown]
# ## Base preço das casas - MAE 67.615, 0.88

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 4.00000e+00,  1.50000e+00,  1.39000e+03, ...,  9.81330e+04,
#          4.77224e+01, -1.22332e+02],
#        [ 3.00000e+00,  1.50000e+00,  1.45000e+03, ...,  9.81330e+04,
#          4.77725e+01, -1.22349e+02],
#        [ 5.00000e+00,  2.75000e+00,  2.86000e+03, ...,  9.80520e+04,
#          4.77082e+01, -1.22104e+02],
#        ...,
#        [ 3.00000e+00,  2.25000e+00,  2.36000e+03, ...,  9.80420e+04,
#          4.73856e+01, -1.22158e+02],
#        [ 4.00000e+00,  2.00000e+00,  2.37000e+03, ...,  9.80010e+04,
#          4.72831e+01, -1.22279e+02],
#        [ 4.00000e+00,  2.25000e+00,  2.38000e+03, ...,  9.80080e+04,
#          4.76126e+01, -1.22120e+02]])

# %%
y_casas_treinamento
# Out:
# array([400000., 430000., 720000., ..., 431000., 411000., 699900.])

# %%
X_casas_teste
# Out:
# array([[ 2.00000e+00,  1.50000e+00,  1.43000e+03, ...,  9.81250e+04,
#          4.77222e+01, -1.22290e+02],
#        [ 4.00000e+00,  3.25000e+00,  4.67000e+03, ...,  9.80050e+04,
#          4.76350e+01, -1.22164e+02],
#        [ 2.00000e+00,  7.50000e-01,  1.44000e+03, ...,  9.81070e+04,
#          4.76707e+01, -1.22364e+02],
#        ...,
#        [ 3.00000e+00,  2.50000e+00,  2.15000e+03, ...,  9.80580e+04,
#          4.74514e+01, -1.22089e+02],
#        [ 3.00000e+00,  1.75000e+00,  1.48000e+03, ...,  9.80320e+04,
#          4.73657e+01, -1.22280e+02],
#        [ 3.00000e+00,  1.00000e+00,  1.32000e+03, ...,  9.80920e+04,
#          4.73120e+01, -1.22183e+02]])

# %%
regressor_random_forest_casas = RandomForestRegressor(n_estimators=100)
regressor_random_forest_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# RandomForestRegressor()

# %%
regressor_random_forest_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.9806907301584408

# %%
regressor_random_forest_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.880486875691124

# %%
previsoes = regressor_random_forest_casas.predict(X_casas_teste)
previsoes
# Out:
# array([ 302995.23, 1739226.9 ,  525342.52, ...,  365333.38,  236111.96,
#         203046.87])

# %%
y_casas_teste
# Out:
# array([ 297000., 1578000.,  562100., ...,  380000.,  268000.,  206000.])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 67798.23136559466

# %% [markdown]
# # SVM

# %% [markdown]
# ## Base plano de saúde

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
# Kernel linear
from sklearn.svm import SVR
regressor_svr_saude_linear = SVR(kernel = 'linear')
regressor_svr_saude_linear.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(kernel='linear')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saude_linear.predict(X_plano_saude2), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="3e45a67b-fa22-47ec-9194-6b4b1c822b5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e45a67b-fa22-47ec-9194-6b4b1c822b5b")) {                    Plotly.newPlot(                        "3e45a67b-fa22-47ec-9194-6b4b1c822b5b",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[216.14000000000033,520.0999999999999,824.0600000000004,1128.0199999999995,1431.9800000000005,1735.9399999999996,2039.8999999999996,2343.8599999999997,2647.8200000000006,2951.7799999999997],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"par ...

# %%
# Kernel polinomial
regressor_svr_saude_poly = SVR(kernel='poly', degree=4)
regressor_svr_saude_poly.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(degree=4, kernel='poly')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saude_poly.predict(X_plano_saude2), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="70e9c811-5910-4074-8295-094de68e88d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70e9c811-5910-4074-8295-094de68e88d9")) {                    Plotly.newPlot(                        "70e9c811-5910-4074-8295-094de68e88d9",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18,23,28,33,38,43,48,53,58,63],"xaxis":"x","y":[470,520,630,830,1150,1530,2040,3080,5100,10100],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[18,23,28,33,38,43,48,53,58,63],"y":[374.5071751819414,448.2086650497321,589.3253226432124,830.1001009540422,1209.098100619297,1771.2065699214809,2567.6349047885387,3655.9146487937624,5099.899493155958,6969.7652767393165],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoor ...

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %% [markdown]
# É necessário "normalizar os dados", pois as variáveis estão estão em uma escala muito diferente. Para isso: Standardscaler

# %%
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
X_plano_saude2_scaled = scaler_x.fit_transform(X_plano_saude2)
scaler_y = StandardScaler()
y_plano_saude2_scaled = scaler_y.fit_transform(y_plano_saude2.reshape(-1,1))

# %%
X_plano_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_plano_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
# Kernel rbf
regressor_svr_saude_rbf = SVR(kernel='rbf')
regressor_svr_saude_rbf.fit(X_plano_saude2_scaled, y_plano_saude2_scaled.ravel())
# Out:
# SVR()

# %%
grafico = px.scatter(x = X_plano_saude2_scaled.ravel(), y = y_plano_saude2_scaled.ravel())
grafico.add_scatter(x = X_plano_saude2_scaled.ravel(), y = regressor_svr_saude_rbf.predict(X_plano_saude2_scaled), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="ae21da82-5f3f-45fd-b589-36b7e16f7553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae21da82-5f3f-45fd-b589-36b7e16f7553")) {                    Plotly.newPlot(                        "ae21da82-5f3f-45fd-b589-36b7e16f7553",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"xaxis":"x","y":[-0.7240113561520064,-0.7065652993772592,-0.6681839744728155,-0.598399747373827,-0.48674498401544525,-0.354154952527367,-0.17620517342494613,0.18667280748979442,0.8914935011895789,2.6360991786642933],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"y":[-0.6234807140772864,-0.6329127762510356,-0.5706650687442069,-0.4986650770824684,-0.4463759606657199,-0.36326796984014836,-0.13553889365913357,0.29353246308522923,0.7912281797991034,1.0938296800840372],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %% [markdown]
# Previsão do preço do plano de saúde para 40 anos

# %%
novo = [[40]]

# %%
import array
novo = scaler_x.transform(novo)
novo = array.reshape(1, -1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-88b9088f6c8a> in <module>()
#       1 import array
#       2 novo = scaler_x.transform(novo)
# ----> 3 novo = array.reshape
#
# AttributeError: module 'array' has no attribute 'reshape'

# %%
scaler_y.inverse_transform(regressor_svr_saude_rbf.predict(novo))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-6cda472af567> in <module>()
# ----> 1 scaler_y.inverse_transform(regressor_svr_saude_rbf.predict(novo))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1020             estimator=self,
#    1021             dtype=FLOAT_DTYPES,
# -> 1022             force_all_finite="allow-nan",
#    1023         )
#    1024
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.42259356].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## Base preço das casas - MAE 82.453, 0.73

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 4.00000e+00,  1.50000e+00,  1.39000e+03, ...,  9.81330e+04,
#          4.77224e+01, -1.22332e+02],
#        [ 3.00000e+00,  1.50000e+00,  1.45000e+03, ...,  9.81330e+04,
#          4.77725e+01, -1.22349e+02],
#        [ 5.00000e+00,  2.75000e+00,  2.86000e+03, ...,  9.80520e+04,
#          4.77082e+01, -1.22104e+02],
#        ...,
#        [ 3.00000e+00,  2.25000e+00,  2.36000e+03, ...,  9.80420e+04,
#          4.73856e+01, -1.22158e+02],
#        [ 4.00000e+00,  2.00000e+00,  2.37000e+03, ...,  9.80010e+04,
#          4.72831e+01, -1.22279e+02],
#        [ 4.00000e+00,  2.25000e+00,  2.38000e+03, ...,  9.80080e+04,
#          4.76126e+01, -1.22120e+02]])

# %%
y_casas_treinamento
# Out:
# array([400000., 430000., 720000., ..., 431000., 411000., 699900.])

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
from sklearn.preprocessing import StandardScaler
scaler_x_casas = StandardScaler()
X_casas_treinamento_scaled = scaler_x_casas.fit_transform(X_casas_treinamento)
scaler_y_casas = StandardScaler()
y_casas_treinamento_scaled = scaler_y_casas.fit_transform(y_casas_treinamento.reshape(-1,1))

# %%
X_casas_treinamento_scaled
# Out:
# array([[ 0.67170039, -0.79711466, -0.74522967, ...,  1.03727271,
#          1.17348387, -0.83797629],
#        [-0.38696772, -0.79711466, -0.68028398, ...,  1.03727271,
#          1.53476983, -0.95879989],
#        [ 1.7303685 ,  0.82292131,  0.84593978, ..., -0.48008241,
#          1.07108346,  0.78248142],
#        ...,
#        [-0.38696772,  0.17490692,  0.30472568, ..., -0.66741021,
#         -1.25528083,  0.3986888 ],
#        [ 0.67170039, -0.14910028,  0.31554996, ..., -1.43545415,
#         -1.99443873, -0.46129094],
#        [ 0.67170039,  0.17490692,  0.32637425, ..., -1.3043247 ,
#          0.38168351,  0.66876509]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[-0.38454326],
#        [-0.3024967 ],
#        [ 0.49062008],
#        ...,
#        [-0.29976181],
#        [-0.35445952],
#        [ 0.43564888]])

# %%
X_casas_treinamento_scaled.shape, y_casas_treinamento_scaled.shape
# Out:
# ((15129, 16), (15129, 1))

# %%
X_casas_teste_scaled = scaler_x_casas.transform(X_casas_teste)
y_casas_teste_scaled = scaler_y_casas.transform(y_casas_teste.reshape(-1,1))

# %%
X_casas_teste_scaled.shape, y_casas_teste_scaled.shape
# Out:
# ((6484, 16), (6484, 1))

# %%
X_casas_teste_scaled
# Out:
# array([[-1.44563583, -0.79711466, -0.70193254, ...,  0.88741047,
#          1.17204161, -0.53947092],
#        [ 0.67170039,  1.47093569,  2.80513482, ..., -1.36052304,
#          0.54321655,  0.35604518],
#        [-1.44563583, -1.76913625, -0.69110826, ...,  0.55022044,
#          0.80065984, -1.06540895],
#        ...,
#        [-0.38696772,  0.49891411,  0.07741576, ..., -0.36768574,
#         -0.78077751,  0.88909048],
#        [-0.38696772, -0.47310747, -0.64781113, ..., -0.854738  ,
#         -1.39878563, -0.46839822],
#        [-0.38696772, -1.44512905, -0.82099964, ...,  0.26922876,
#         -1.78603226,  0.22100704]])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.66623646],
#        [ 2.83715179],
#        [ 0.05878167],
#        ...,
#        [-0.43924097],
#        [-0.74554814],
#        [-0.91511104]])

# %%
regressor_svr_casas = SVR(kernel='rbf')
regressor_svr_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# SVR()

# %%
regressor_svr_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.8123337393146999

# %%
regressor_svr_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.7374454724624955

# %%
previsoes = regressor_svr_casas.predict(X_casas_teste_scaled)
previsoes
# Out:
# array([-0.54571552,  3.46454238,  0.02286424, ..., -0.46405796,
#        -0.91113329, -1.03334346])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.66623646],
#        [ 2.83715179],
#        [ 0.05878167],
#        ...,
#        [-0.43924097],
#        [-0.74554814],
#        [-0.91511104]])

# %%
y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-b30882b4a19b> in <module>()
#       1 y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
# ----> 2 previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1020             estimator=self,
#    1021             dtype=FLOAT_DTYPES,
# -> 1022             force_all_finite="allow-nan",
#    1023         )
#    1024
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.54571552  3.46454238  0.02286424 ... -0.46405796 -0.91113329
#  -1.03334346].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
y_casas_teste_inverse
# Out:
# array([[ 297000.],
#        [1578000.],
#        [ 562100.],
#        ...,
#        [ 380000.],
#        [ 268000.],
#        [ 206000.]])

# %%
previsoes_inverse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-92442ad8a149> in <module>()
# ----> 1 previsoes_inverse
#
# NameError: name 'previsoes_inverse' is not defined

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-3d5f0acd3cb8> in <module>()
#       1 from sklearn.metrics import mean_absolute_error
# ----> 2 mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
#
# NameError: name 'previsoes_inverse' is not defined

# %% [markdown]
# # Redes neurais artificiais

# %% [markdown]
# ## Base plano de saúde

# %% [markdown]
# Escalonamento das variáveis

# %%
X_plano_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_plano_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
from sklearn.neural_network import MLPRegressor
regressor_rna_saude = MLPRegressor(max_iter=1000)
regressor_rna_saude.fit(X_plano_saude2_scaled, y_plano_saude2_scaled.ravel())
# Out:
# MLPRegressor(max_iter=1000)

# %%
regressor_rna_saude.score(X_plano_saude2_scaled, y_plano_saude2_scaled)
# Out:
# 0.9571210182686064

# %%
grafico = px.scatter(x = X_plano_saude2_scaled.ravel(), y = y_plano_saude2_scaled.ravel())
grafico.add_scatter(x = X_plano_saude2_scaled.ravel(), y = regressor_rna_saude.predict(X_plano_saude2_scaled), name = 'Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="0122b514-fce2-4792-89ef-d2b009017fc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0122b514-fce2-4792-89ef-d2b009017fc0")) {                    Plotly.newPlot(                        "0122b514-fce2-4792-89ef-d2b009017fc0",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"xaxis":"x","y":[-0.7240113561520064,-0.7065652993772592,-0.6681839744728155,-0.598399747373827,-0.48674498401544525,-0.354154952527367,-0.17620517342494613,0.18667280748979442,0.8914935011895789,2.6360991786642933],"yaxis":"y","type":"scatter"},{"name":"Regress\u00e3o","x":[-1.5666989036012806,-1.2185435916898848,-0.8703882797784892,-0.5222329678670935,-0.17407765595569785,0.17407765595569785,0.5222329678670935,0.8703882797784892,1.2185435916898848,1.5666989036012806],"y":[-0.7314669130042999,-0.6924232542042399,-0.6611531053905124,-0.6087897656764308,-0.5408618154254254,-0.4418316650325013,-0.21398943440848317,0.4011376264154262,1.2874217092875357,2.1739530365362834],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %% [markdown]
# Previsão do custo do plano de saúde para 40 anos.
# (Escalonar)

# %%
novo = [[40]]
novo = scaler_x.transform(novo)
novo
# Out:
# array([[-0.03481553]])

# %%
scaler_y.inverse_transform(regressor_rna_saude.predict(novo))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-bd8f458b7bcc> in <module>()
# ----> 1 scaler_y.inverse_transform(regressor_rna_saude.predict(novo))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1020             estimator=self,
#    1021             dtype=FLOAT_DTYPES,
# -> 1022             force_all_finite="allow-nan",
#    1023         )
#    1024
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.51170928].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## Base preço das casas - MAE 76.311, 0.87

# %%
X_casas_treinamento_scaled.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento_scaled
# Out:
# array([[ 0.67170039, -0.79711466, -0.74522967, ...,  1.03727271,
#          1.17348387, -0.83797629],
#        [-0.38696772, -0.79711466, -0.68028398, ...,  1.03727271,
#          1.53476983, -0.95879989],
#        [ 1.7303685 ,  0.82292131,  0.84593978, ..., -0.48008241,
#          1.07108346,  0.78248142],
#        ...,
#        [-0.38696772,  0.17490692,  0.30472568, ..., -0.66741021,
#         -1.25528083,  0.3986888 ],
#        [ 0.67170039, -0.14910028,  0.31554996, ..., -1.43545415,
#         -1.99443873, -0.46129094],
#        [ 0.67170039,  0.17490692,  0.32637425, ..., -1.3043247 ,
#          0.38168351,  0.66876509]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[-0.38454326],
#        [-0.3024967 ],
#        [ 0.49062008],
#        ...,
#        [-0.29976181],
#        [-0.35445952],
#        [ 0.43564888]])

# %%
X_casas_teste_scaled.shape
# Out:
# (6484, 16)

# %%
(16 + 1) / 2
# Out:
# 8.5

# %% [markdown]
# 2 camadas ocultas com 16 atributos e 9 neurônios

# %%
# 16 -> 9 -> 9 -> 1
regressor_rna_casas = MLPRegressor(max_iter=1000, hidden_layer_sizes=(9,9))
regressor_rna_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# MLPRegressor(hidden_layer_sizes=(9, 9), max_iter=1000)

# %%
regressor_rna_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.8926469906018549

# %%
regressor_rna_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.8707177986077214

# %%
previsoes = regressor_rna_casas.predict(X_casas_teste_scaled)
previsoes
# Out:
# array([-0.57783146,  4.18086558,  0.07608512, ..., -0.58129662,
#        -0.8234378 , -0.88138989])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.66623646],
#        [ 2.83715179],
#        [ 0.05878167],
#        ...,
#        [-0.43924097],
#        [-0.74554814],
#        [-0.91511104]])

# %%
y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-b30882b4a19b> in <module>()
#       1 y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
# ----> 2 previsoes_inverse = scaler_y_casas.inverse_transform(previsoes)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1020             estimator=self,
#    1021             dtype=FLOAT_DTYPES,
# -> 1022             force_all_finite="allow-nan",
#    1023         )
#    1024
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.57783146  4.18086558  0.07608512 ... -0.58129662 -0.8234378
#  -0.88138989].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
y_casas_teste_inverse

# %%
previsoes_inverse

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
